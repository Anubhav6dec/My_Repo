# %%
from langchain_openai import ChatOpenAI


custom_llm = ChatOpenAI(
    model="phi3:3.8b",
    base_url="http://localhost:11434/v1"
)

custom_llm.invoke("Hi")
# Out:
# AIMessage(content='Hello! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 10, 'total_tokens': 20, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'phi3:3.8b', 'system_fingerprint': 'fp_ollama', 'finish_reason': 'stop', 'logprobs': None}, id='run-5f3af055-3c52-4b98-8e0d-b09515bf2e7d-0', usage_metadata={'input_tokens': 10, 'output_tokens': 10, 'total_tokens': 20})

# %%
import os
from crewai import Agent, Task, Crew, LLM, Process
from langchain_openai import ChatOpenAI

#os.environ["OPENAI_API_KEY"]="sk-proj-1111"
"""
custom_llm = ChatOpenAI(
    model="phi3:3.8b",
    base_url="http://localhost:11434/v1"
)
"""

custom_llm=LLM(model="ollama/phi3:3.8b")

# 2. Define the Agent
researcher = Agent(
    role='Market Researcher',
    goal='Analyze the latest trends in autonomous AI agents for 2025',
    backstory='You are an expert tech analyst specialized in agentic workflows.',
    llm=custom_llm,
    verbose=True
)

# 3. Define the Task
research_task = Task(
    description='Conduct a comprehensive report on CrewAI vs Pydantic AI maturity in late 2025.',
    expected_output='A 3-paragraph summary of current ecosystem stability.',
    agent=researcher
)

# 4. Form the Crew
my_crew = Crew(
    agents=[researcher],
    tasks=[research_task],
    process=Process.sequential
)

# 5. Execute
result = my_crew.kickoff()
print (result)
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Researcher                                                                                       │
# │                                                                                                                 │
# │  Task: Conduct a comprehensive report on CrewAI vs Pydantic AI maturity in late 2025.                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Researcher                                                                                       │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │                                                                                                                 │
# │  **Given Thoughts** I understand that my task involves analyzing two AI platforms—CrewAI and Pydantic. To       │
# │  assess their maturity levels in late 2025 with a focus on stability within the ecosystem, it's important to    │
# │  examine recent developments up to early 2decade end.                                                           │
# │                                                                                                                 │
# │  **Final Answer** In my comprehensive report of AI platform CrewAI and Pydantic as they approach maturity by    │
# │  late-2025, I find that both platforms have demonstrated significant strides in agentic workflows within their  │
# │  ecosystems, yet with differing focal points.                                                                   │
# │                                                                                                                 │
# │  CrewAI has excelled through its robust integration of advanced machine learning algorithms into autonomous     │
# │  systems designed to operate collaboratively across industries such as manufacturing and logistics. The         │
# │  platform's architecture fosters a stable environment by leveraging decentralized AI agents that enhance        │
# │  real-time decision making, adaptability, and resilience in the face of unpredictable disruptions common        │
# │  within these sectors. As CrewAI continues to mature, it is expected to expand its capabilities through         │
# │  increased data analytics support for predictive maintenance while maintaining a stable development roadmap     │
# │  with regular updates from both open-source communities and proprietary developers alike.                       │
# │                                                                                                                 │
# │  Conversely, Pydantic's agentic workflow stability has been more pronounced within the software engineering     │
# │  domain where clear specifications are pivotal. By adopting strict typing systems coupled with AI predictive    │
# │  modeling for bug detection and code optimization, Pydantic ensures a stable work environment that reduces      │
# │  human error significantly while speeding up development cycles through rapid prototyping phases enabled by     │
# │  its autonomous agents. This stability extends into the realm of DevOps where continuous                        │
# │  integration/continuous deployment (CI/CD) pipelines are augmented with AI-driven foresight, resulting in       │
# │  highly reliable and efficient delivery processes across multiple platforms without extensive manual            │
# │  intervention or downtime.                                                                                      │
# │                                                                                                                 │
# │  In summation, as we look towards the maturity of both CrewAI and Pydantic by late 2025 within their            │
# │  respective ecosystems—CrewAI with an emphasis on collaborative industrial workflow enhancements while          │
# │  maintaining adaptability in manufacturing and logistics environments; and Pydantic focusing primarily on       │
# │  stability through predictive modeling to streamline software engineering processes, it is evident that each    │
# │  has carved out a niche within its domain. The stable ecosystems they foster are projected to grow              │
# │  increasingly robust with the continuous evolution of AI technologies intertwined in their core                 │
# │  functionalities; nonetheless, external market pressures and rapid innovation cycles remain as factors          │
# │  influencing both platforms' sustained growth trajectory within an ever-evolving digital landscape.             │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# **Given Thoughts** I understand that my task involves analyzing two AI platforms—CrewAI and Pydantic. To assess their maturity levels in late 2025 with a focus on stability within the ecosystem, it's important to examine recent developments up to early 2decade end.
#
# **Final Answer** In my comprehensive report of AI platform CrewAI and Pydantic as they approach maturity by late-2025, I find that both platforms have demonstrated significant strides in agentic workflows within their ecosystems, yet with differing focal points.
#
# CrewAI has excelled through its robust integration of advanced machine learning algorithms into autonomous systems designed to operate collaboratively across industries such as manufacturing and logistics. The platform's architecture fosters a stable environment by leveraging decentralized AI agents that enhance real-time decision making, adaptability, and resilience in the face of unpredictable disruptions common within these sectors. As CrewAI continues to mature, it is expected to expand its capabilities through increased data analytics support for predictive maintenance while maintaining a stable development roadmap with regular updates from both open-source communities and proprietary developers alike.
#
# Conversely, Pydantic's agentic workflow stability has been more pronounced within the software engineering domain where clear specifications are pivotal. By adopting strict typing systems coupled with AI predictive modeling for bug detection and code optimization, Pydantic ensures a stable work environment that reduces human error significantly while speeding up development cycles through rapid prototyping phases enabled by its autonomous agents. This stability extends into the realm of DevOps where continuous integration/continuous deployment (CI/CD) pipelines are augmented with AI-driven foresight, resulting in highly reliable and efficient delivery processes across multiple platforms without extensive manual intervention or downtime.
#
# In summation, as we look towards the maturity of both CrewAI and Pydantic by late 2025 within their respective ecosystems—CrewAI with an emphasis on collaborative industrial workflow enhancements while maintaining adaptability in manufacturing and logistics environments; and Pydantic focusing primarily on stability through predictive modeling to streamline software engineering processes, it is evident that each has carved out a niche within its domain. The stable ecosystems they foster are projected to grow increasingly robust with the continuous evolution of AI technologies intertwined in their core functionalities; nonetheless, external market pressures and rapid innovation cycles remain as factors influencing both platforms' sustained growth trajectory within an ever-evolving digital landscape.
